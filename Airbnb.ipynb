# %% [markdown]
# <a href="https://colab.research.google.com/github/ANURADHA123-SINGH/Data-Analaytics-project-s-/blob/main/Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone 'https://github.com/HarshvardhanSingh-13/Datasets'
# Out:
# Cloning into 'Datasets'...
# remote: Enumerating objects: 303, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 303 (delta 14), reused 0 (delta 0), pack-reused 242 (from 1)
# Receiving objects: 100% (303/303), 301.35 MiB | 16.82 MiB/s, done.
# Resolving deltas: 100% (128/128), done.
# Updating files: 100% (235/235), done.

# %%
import pandas as pd
df = pd.read_csv('/content/Datasets/Airbnb/airbnb.csv')

# %%
df.head()
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New     NaN
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New     NaN
#
#                                host_name      host_id  \
# 0    Entire bungalow hosted by Mehmetcan  357334205.0
# 1           Entire villa hosted by Fatih  386223873.0
# 2          Entire cabin hosted by Giorgi  409690853.0
# 3        Entire bungalow hosted by Melih  401873242.0
# 4  Entire bungalow hosted by Arp Sapanca  414884116.0
#
#                     address                                features  \
# 0  Kartepe, Kocaeli, Turkey    2 guests,2 bedrooms,1 bed,1 bathroom
# 1      Kaş, Antalya, Turkey  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2          Imereti, Georgia    4 guests,1 bedroom,3 beds,1 bathroom
# 3  Sapanca, Sakarya, Turkey    4 guests,1 bedroom,2 beds,1 bathroom
# 4  Sapanca, Sakarya, Turkey     2 guests,1 bedroom,1 bed,1 bathroom
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2  Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
#
#                                            img_links              price
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3  https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4  https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night

# %% [markdown]
# ## 1) overall data analytics

# %%
df.describe()
# Out:
#                  id       host_id
# count  1.445600e+04  1.401700e+04
# mean   7.138227e+16  1.619384e+08
# std    1.962072e+17  1.403407e+08
# min    1.313100e+04  2.303900e+04
# 25%    2.047078e+07  3.603925e+07
# 50%    3.524320e+07  1.243490e+08
# 75%    4.951689e+07  2.607109e+08
# max    7.017905e+17  4.758973e+08
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14456 entries, 0 to 14455
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            14456 non-null  int64
#  1   name          14455 non-null  object
#  2   rating        14456 non-null  object
#  3   reviews       11712 non-null  object
#  4   host_name     14455 non-null  object
#  5   host_id       14017 non-null  float64
#  6   address       14429 non-null  object
#  7   features      14429 non-null  object
#  8   amenities     13467 non-null  object
#  9   safety_rules  14247 non-null  object
#  10  hourse_rules  14247 non-null  object
#  11  img_links     14429 non-null  object
#  12  price         14456 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# id                 0
# name               1
# rating             0
# reviews         2744
# host_name          1
# host_id          439
# address           27
# features          27
# amenities        989
# safety_rules     209
# hourse_rules     209
# img_links         27
# price              0
# dtype: int64

# %%
df[df['rating'] == 'New']
# Out:
#                        id                                               name  \
# 1                50891766  Authentic Beach Architect Sheltered Villa with...
# 4                51245886                                      Bungalov Ev 2
# 5                48650769                      CasaMia White Suite Treehouse
# 6                50765985                                     Ladin Bungalow
# 7                40947216                                     Lavender House
# ...                   ...                                                ...
# 14440            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# 14441            41257160    Romantic stay at Tent galaxy villa with jacuzzi
# 14443  621201623913222432        Kintamani Glamping Black Lava camp Potato 2
# 14445            44045739                                       Tambu a mare
# 14449  640474109823176234                            Holiday home, Plemmirio
#
#       rating reviews                                       host_name  \
# 1        New     NaN                    Entire villa hosted by Fatih
# 4        New     NaN           Entire bungalow hosted by Arp Sapanca
# 5        New     NaN                     Treehouse hosted by Casamia
# 6        New     NaN               Entire bungalow hosted by Stephen
# 7        New     NaN                       Treehouse hosted by Caner
# ...      ...     ...                                             ...
# 14440    New       1                          Pension hosted by Onda
# 14441    New       1                        Dome hosted by Pt. Archi
# 14443    New     NaN  Private room in dome hosted by Black Lava Camp
# 14445    New     NaN                     Entire home hosted by Maria
# 14449    New     NaN           Entire home hosted by Daphne Belvilla
#
#            host_id                                            address  \
# 1      386223873.0                               Kaş, Antalya, Turkey
# 4      414884116.0                           Sapanca, Sakarya, Turkey
# 5      261290482.0                           Sapanca, Sakarya, Turkey
# 6       15084529.0                               Kaş, Antalya, Turkey
# 7      318794897.0                            Akçalı, Giresun, Turkey
# ...            ...                                                ...
# 14440  331826286.0  Nam-myeon, Jeongseon-gun, Gangwon Province, So...
# 14441  110392424.0            Kecamatan Kuta Selatan, Bali, Indonesia
# 14443  454606239.0                         Kintamani, Bali, Indonesia
# 14445  122986750.0                            Augusta, Sicilia, Italy
# 14449  385223440.0                           Syracuse, Sicilia, Italy
#
#                                                features  \
# 1                4 guests,2 bedrooms,2 beds,2 bathrooms
# 4                   2 guests,1 bedroom,1 bed,1 bathroom
# 5                  2 guests,1 bedroom,2 beds,1 bathroom
# 6                   2 guests,1 bedroom,1 bed,1 bathroom
# 7                  8 guests,1 bedroom,2 beds,1 bathroom
# ...                                                 ...
# 14440                     5 guests,1 bedroom,1 bathroom
# 14441               2 guests,1 bedroom,1 bed,1 bathroom
# 14443  2 guests,1 bedroom,1 bed,Shared toilet with sink
# 14445           5 guests,1 bedroom,2 beds,1.5 bathrooms
# 14449            8 guests,4 bedrooms,4 beds,2 bathrooms
#
#                                                amenities  \
# 1      Kitchen,Wifi,Dedicated workspace,Free parking ...
# 4      Kitchen,Wifi,Free parking on premises,TV,Air c...
# 5      Lake view,Mountain view,Waterfront,Wifi,Dedica...
# 6      Garden view,Mountain view,Kitchen,Wifi,Dedicat...
# 7      Wifi,Dedicated workspace,Free parking on premi...
# ...                                                  ...
# 14440  Waterfront,Kitchen,Wifi,Free parking on premis...
# 14441  Wifi,Free parking on premises,Private pool,Pet...
# 14443  Free parking on premises,Pool,Fire pit,Long-te...
# 14445  Beach access – Beachfront,Kitchen,Wifi,Dedicat...
# 14449  Kitchen,Wifi,Dedicated workspace,Free on-stree...
#
#                                             safety_rules  \
# 1      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 4      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 5      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 6      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 7      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14440  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14441  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14443  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14445  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14449  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                             hourse_rules  \
# 1      Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 4      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 5      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 6      Check-in: After 3:00 pm,Check out: 11:00 am,No...
# 7      Check-in: Flexible,Self check-in with building...
# ...                                                  ...
# 14440  Check-in: 3:00 pm - 10:00 pm,Check out: 11:00 ...
# 14441  Check-in: After 2:00 pm,Self check-in with loc...
# 14443                            Check-in: After 3:00 pm
# 14445  Check-in: 1:00 pm - 8:00 pm,Check out: 11:00 a...
# 14449  Check-in: 2:00 pm - 8:00 pm,Check out: 10:00 a...
#
#                                                img_links              price
# 1      https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 4      https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
# 5      https://a0.muscache.com/im/pictures/miso/Hosti...  ₹14,729 per night
# 6      https://a0.muscache.com/im/pictures/prohost-ap...  ₹12,312 per night
# 7      https://a0.muscache.com/im/pictures/97046585-1...  ₹13,655 per night
# ...                                                  ...                ...
# 14440  https://a0.muscache.com/im/pictures/prohost-ap...   ₹4,980 per night
# 14441  https://a0.muscache.com/im/pictures/641046c0-e...  ₹10,729 per night
# 14443  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹3,428 per night
# 14445  https://a0.muscache.com/im/pictures/8cac9ffa-5...   ₹8,841 per night
# 14449  https://a0.muscache.com/im/pictures/prohost-ap...  ₹20,311 per night
#
# [4841 rows x 13 columns]

# %%
df
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...    New
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 4      51245886                                      Bungalov Ev 2    New
# ...         ...                                                ...    ...
# 14451  44697740            Brown Dome House No. 3, full of healing   4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 14453  32977697                                   Paradise Eco Hub   4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews                              host_name      host_id  \
# 0          64    Entire bungalow hosted by Mehmetcan  357334205.0
# 1         NaN           Entire villa hosted by Fatih  386223873.0
# 2          68          Entire cabin hosted by Giorgi  409690853.0
# 3          13        Entire bungalow hosted by Melih  401873242.0
# 4         NaN  Entire bungalow hosted by Arp Sapanca  414884116.0
# ...       ...                                    ...          ...
# 14451      16                   Dome hosted by Aidan  161552316.0
# 14452       6                  Tent hosted by Martha  118954227.0
# 14453       3   Private room in dome hosted by Silas  175214568.0
# 14454       7                 Dome hosted by Cempaka     718423.0
# 14455      13                    Dome hosted by Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 1                                   Kaş, Antalya, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 4                               Sapanca, Sakarya, Turkey
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 1            4 guests,2 bedrooms,2 beds,2 bathrooms
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 4               2 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 14451                          4 guests,8 bathrooms
# 14452     2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 beds,1 private bathroom
# 14454      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 1      Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4      Kitchen,Wifi,Free parking on premises,TV,Air c...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1      Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# ...                                                  ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                            Check-in: After 3:00 pm
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...
#
#                                                img_links              price
# 0      https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1      https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2      https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3      https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4      https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
# ...                                                  ...                ...
# 14451  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,288 per night
# 14452  https://a0.muscache.com/im/pictures/5ba944b2-b...  ₹15,200 per night
# 14453  https://a0.muscache.com/im/pictures/1f442c84-4...   ₹9,103 per night
# 14454  https://a0.muscache.com/im/pictures/105116799/...  ₹42,262 per night
# 14455  https://a0.muscache.com/im/pictures/9b04ee4c-c...   ₹9,909 per night
#
# [14456 rows x 13 columns]

# %%
display(df[df.isnull().any(axis =1)])
# Out:
#                        id                                               name  \
# 1                50891766  Authentic Beach Architect Sheltered Villa with...
# 4                51245886                                      Bungalov Ev 2
# 5                48650769                      CasaMia White Suite Treehouse
# 6                50765985                                     Ladin Bungalow
# 7                40947216                                     Lavender House
# ...                   ...                                                ...
# 14436  621278037552014887        Kintamani Glamping Black Lava Camp Potato 3
# 14439  624406715458043020         Kintamani Glamping Black Lava Camp Onion 3
# 14443  621201623913222432        Kintamani Glamping Black Lava camp Potato 2
# 14445            44045739                                       Tambu a mare
# 14449  640474109823176234                            Holiday home, Plemmirio
#
#       rating reviews                                       host_name  \
# 1        New     NaN                    Entire villa hosted by Fatih
# 4        New     NaN           Entire bungalow hosted by Arp Sapanca
# 5        New     NaN                     Treehouse hosted by Casamia
# 6        New     NaN               Entire bungalow hosted by Stephen
# 7        New     NaN                       Treehouse hosted by Caner
# ...      ...     ...                                             ...
# 14436    New     NaN  Private room in dome hosted by Black Lava Camp
# 14439    New     NaN  Private room in dome hosted by Black Lava Camp
# 14443    New     NaN  Private room in dome hosted by Black Lava Camp
# 14445    New     NaN                     Entire home hosted by Maria
# 14449    New     NaN           Entire home hosted by Daphne Belvilla
#
#            host_id                     address  \
# 1      386223873.0        Kaş, Antalya, Turkey
# 4      414884116.0    Sapanca, Sakarya, Turkey
# 5      261290482.0    Sapanca, Sakarya, Turkey
# 6       15084529.0        Kaş, Antalya, Turkey
# 7      318794897.0     Akçalı, Giresun, Turkey
# ...            ...                         ...
# 14436  454606239.0  Kintamani, Bali, Indonesia
# 14439  454606239.0  Kintamani, Bali, Indonesia
# 14443  454606239.0  Kintamani, Bali, Indonesia
# 14445  122986750.0     Augusta, Sicilia, Italy
# 14449  385223440.0    Syracuse, Sicilia, Italy
#
#                                                features  \
# 1                4 guests,2 bedrooms,2 beds,2 bathrooms
# 4                   2 guests,1 bedroom,1 bed,1 bathroom
# 5                  2 guests,1 bedroom,2 beds,1 bathroom
# 6                   2 guests,1 bedroom,1 bed,1 bathroom
# 7                  8 guests,1 bedroom,2 beds,1 bathroom
# ...                                                 ...
# 14436  2 guests,1 bedroom,1 bed,Shared toilet with sink
# 14439  2 guests,1 bedroom,1 bed,Shared toilet with sink
# 14443  2 guests,1 bedroom,1 bed,Shared toilet with sink
# 14445           5 guests,1 bedroom,2 beds,1.5 bathrooms
# 14449            8 guests,4 bedrooms,4 beds,2 bathrooms
#
#                                                amenities  \
# 1      Kitchen,Wifi,Dedicated workspace,Free parking ...
# 4      Kitchen,Wifi,Free parking on premises,TV,Air c...
# 5      Lake view,Mountain view,Waterfront,Wifi,Dedica...
# 6      Garden view,Mountain view,Kitchen,Wifi,Dedicat...
# 7      Wifi,Dedicated workspace,Free parking on premi...
# ...                                                  ...
# 14436  Lake view,Mountain view,Free parking on premis...
# 14439  Free parking on premises,Pool,Long-term stays ...
# 14443  Free parking on premises,Pool,Fire pit,Long-te...
# 14445  Beach access – Beachfront,Kitchen,Wifi,Dedicat...
# 14449  Kitchen,Wifi,Dedicated workspace,Free on-stree...
#
#                                             safety_rules  \
# 1      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 4      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 5      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 6      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 7      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14436  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14439  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14443  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14445  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14449  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                             hourse_rules  \
# 1      Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 4      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 5      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 6      Check-in: After 3:00 pm,Check out: 11:00 am,No...
# 7      Check-in: Flexible,Self check-in with building...
# ...                                                  ...
# 14436                            Check-in: After 3:00 pm
# 14439                            Check-in: After 3:00 pm
# 14443                            Check-in: After 3:00 pm
# 14445  Check-in: 1:00 pm - 8:00 pm,Check out: 11:00 a...
# 14449  Check-in: 2:00 pm - 8:00 pm,Check out: 10:00 a...
#
#                                                img_links              price
# 1      https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 4      https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
# 5      https://a0.muscache.com/im/pictures/miso/Hosti...  ₹14,729 per night
# 6      https://a0.muscache.com/im/pictures/prohost-ap...  ₹12,312 per night
# 7      https://a0.muscache.com/im/pictures/97046585-1...  ₹13,655 per night
# ...                                                  ...                ...
# 14436  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹3,490 per night
# 14439  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹3,864 per night
# 14443  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹3,428 per night
# 14445  https://a0.muscache.com/im/pictures/8cac9ffa-5...   ₹8,841 per night
# 14449  https://a0.muscache.com/im/pictures/prohost-ap...  ₹20,311 per night
#
# [3553 rows x 13 columns]

# %%
df['amenities'].mode()[0]
# Out:
# 'Long-term stays allowed,Unavailable: Carbon monoxide alarmCarbon monoxide alarm,Unavailable: Smoke alarmSmoke alarm'

# %%
df['hourse_rules'].mode()[0]
# Out:
# 'Check-in: After 3:00 pm'

# %%
df.dropna(subset=['reviews'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id         207
# address           0
# features          0
# amenities       716
# safety_rules     95
# hourse_rules     95
# img_links         0
# price             0
# dtype: int64

# %%
df['host_id'].mode()
# Out:
# 0    157378426.0
# Name: host_id, dtype: float64

# %%
df.drop_duplicates(subset=['id'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id         169
# address           0
# features          0
# amenities       670
# safety_rules     92
# hourse_rules     92
# img_links         0
# price             0
# dtype: int64

# %%
df[df['id'] == 31378793]['host_name']
# Out:
# 861    Designer villa with private vineyard, sommelier
# Name: host_name, dtype: object

# %%
df[df['host_id'].isnull()]
# Out:
#                        id                         name rating reviews  \
# 725    588250406117563784  Maison Cardinal Furstemberg    5.0       6
# 801              35839817                       Icaria    5.0       3
# 861              31378793               Villa Grenache    New       1
# 2337             20473398                Villa Sawarin    New       1
# 2339             20470768         Samujana Twenty-Four    New       1
# ...                   ...                          ...    ...     ...
# 12277            26202362                Villa Ferraia   4.87      15
# 12286            26202400             Sole del Chianti   4.89      19
# 12301            20473328        Il Parco del Principe    New       2
# 12348            20472010                 Casa Lazzari   4.82      11
# 12394            20204291               Chateau d'Azur    New       1
#
#                                                host_name  host_id  \
# 725          Luxury stay in Paris, Île-de-France, France      NaN
# 801    Luxury stay in Cape Town, Western Cape, South ...      NaN
# 861      Designer villa with private vineyard, sommelier      NaN
# 2337            Luxury stay in Thalang, Phuket, Thailand      NaN
# 2339   Modernism and vintage Thai art on coastal hill...      NaN
# ...                                                  ...      ...
# 12277      Ultra private hilltop retreat near Monticiano      NaN
# 12286  Luxury stay in Tavarnelle Val di Pesa, Florenc...      NaN
# 12301                Neo-Gothic garden villa near Chiusi      NaN
# 12348                                       Casa Lazzari      NaN
# 12394                  Chateau d'Azur - 15Br - Sleeps 30      NaN
#
#                                           address  \
# 725                  Paris, Île-de-France, France
# 801         Cape Town, Western Cape, South Africa
# 861         Cape Town, Western Cape, South Africa
# 2337                    Thalang, Phuket, Thailand
# 2339              Koh Samui, Suratthani, Thailand
# ...                                           ...
# 12277                        Tocchi, Siena, Italy
# 12286     Tavarnelle Val di Pesa, Florence, Italy
# 12301                        Chiusi, Siena, Italy
# 12348                   Umbertide, Perugia, Italy
# 12394  Frejus, Provence-Alpes-Côte d'Azur, France
#
#                                            features amenities  \
# 725          7 guests,3 bedrooms,3 beds,4 bathrooms       NaN
# 801         10 guests,5 bedrooms,5 beds,5 bathrooms       NaN
# 861         10 guests,5 bedrooms,5 beds,5 bathrooms       NaN
# 2337      16 guests,9 bedrooms,10 beds,10 bathrooms       NaN
# 2339       16 guests,8 bedrooms,8 beds,10 bathrooms       NaN
# ...                                             ...       ...
# 12277  16 guests,14 bedrooms,14 beds,15.5 bathrooms       NaN
# 12286    16 guests,10 bedrooms,11 beds,11 bathrooms       NaN
# 12301     16 guests,8 bedrooms,9 beds,8.5 bathrooms       NaN
# 12348       12 guests,6 bedrooms,6 beds,8 bathrooms       NaN
# 12394    16 guests,15 bedrooms,17 beds,14 bathrooms       NaN
#
#                                             safety_rules  \
# 725    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
# 801    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 861    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2337   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2339   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# ...                                                  ...
# 12277  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 12286  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 12301  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 12348  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 12394  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
#
#                                             hourse_rules  \
# 725    Check-in: After 5:00 pm,Check out: 11:00 am,Se...
# 801    Check-in: After 2:00 pm,Check out: 10:00 am,No...
# 861    Check-in: After 2:00 pm,Check out: 10:00 am,No...
# 2337   Check-in: After 3:00 pm,Check out: 12:00 pm,No...
# 2339   Check-in: After 3:00 pm,Check out: 12:00 pm,No...
# ...                                                  ...
# 12277  Check-in: After 4:00 pm,Check out: 10:00 am,No...
# 12286  Check-in: 4:00 pm - 6:00 pm,Check out: 10:00 a...
# 12301  Check-in: After 4:00 pm,Check out: 10:00 am,No...
# 12348  Check-in: After 5:00 pm,Check out: 10:00 am,No...
# 12394  Check-in: After 4:00 pm,Check out: 10:00 am,No...
#
#                                                img_links                price
# 725    https://a0.muscache.com/im/pictures/miso/Hosti...  ₹2,38,171 per night
# 801    https://a0.muscache.com/im/pictures/5bdf180f-a...    ₹84,468 per night
# 861    https://a0.muscache.com/im/pictures/dfe31a03-b...    ₹44,239 per night
# 2337   https://a0.muscache.com/im/pictures/009f1d32-c...  ₹3,15,089 per night
# 2339   https://a0.muscache.com/im/pictures/949f5b43-9...  ₹2,73,673 per night
# ...                                                  ...                  ...
# 12277  https://a0.muscache.com/im/pictures/b10bcc29-2...  ₹3,36,853 per night
# 12286  https://a0.muscache.com/im/pictures/153dc0ce-5...  ₹1,19,086 per night
# 12301  https://a0.muscache.com/im/pictures/5db05d12-4...  ₹3,28,914 per night
# 12348  https://a0.muscache.com/im/pictures/6d8db649-7...    ₹80,518 per night
# 12394  https://a0.muscache.com/im/pictures/5c7acb18-f...  ₹6,85,377 per night
#
# [169 rows x 13 columns]

# %%
display(df[df.isnull().any(axis = 1)])
# Out:
#                        id                                               name  \
# 26     625932329535277910                                sapanca Bungalife M
# 132              33343364                          Glamping Forest Edge #No3
# 136              33343138                          Glamping Forest Edge #No2
# 241              33325892          Mao Mao surf (Jungle hut 3: Drunk parrot)
# 261    586461707995407164             A Frame Tiny Cabin with swimming pool.
# ...                   ...                                                ...
# 14119            26155377  IVORY STD Double (Clean room & Care your holiday)
# 14142            33429446                    lovely rest,free island hopping
# 14227            54075486  PIR-Panjal Luxury Glamping Dome in Sethan, Manali
# 14396            53140890    Richland Bali - Private Glamping by The Lake 02
# 14424            22285856                                   LA CASA HIBISCUS
#
#       rating reviews                                          host_name  \
# 26       4.6       5                          Treehouse hosted by Kemal
# 132      New       1          Room in bed and breakfast hosted by Rožle
# 136      New       1          Room in bed and breakfast hosted by Rožle
# 241     4.93      27          Room in bed and breakfast hosted by Marco
# 261      New       1  Private room in bed and breakfast hosted by Fr...
# ...      ...     ...                                                ...
# 14119   4.74      38                     Room in hostel hosted by Ivory
# 14142   4.71      14                      Room in resort hosted by Chan
# 14227    New       2                           Dome hosted by Dipshikha
# 14396    New       2                Private room in dome hosted by Raka
# 14424   4.88      56            Room in nature lodge hosted by Chrystel
#
#            host_id                                            address  \
# 26     457654417.0                         Memnuniye, Sakarya, Turkey
# 132    228484488.0                         Radomlje, Kamnik, Slovenia
# 136    228484488.0                         Radomlje, Kamnik, Slovenia
# 241     13119109.0       General Luna, Surigao del Norte, Philippines
# 261    428123005.0          Moshi Urban, Kilimanjaro Region, Tanzania
# ...            ...                                                ...
# 14119  152784753.0                           Ao Nang, Krabi, Thailand
# 14142  156727997.0                          Langkawi, Kedah, Malaysia
# 14227  370696228.0                    Manali, Himachal Pradesh, India
# 14396  420521923.0                Kecamatan Baturiti, Bali, Indonesia
# 14424   55358262.0  Trou-aux-Biches, Pamplemousses District, Mauri...
#
#                                            features  \
# 26           7 guests,3 bedrooms,4 beds,2 bathrooms
# 132    3 guests,1 bedroom,2 beds,4 shared bathrooms
# 136    3 guests,1 bedroom,2 beds,4 shared bathrooms
# 241     2 guests,1 bedroom,1 bed,1 private bathroom
# 261     2 guests,1 bedroom,1 bed,1 private bathroom
# ...                                             ...
# 14119      2 guests,Studio,1 bed,1 private bathroom
# 14142  4 guests,1 bedroom,3 beds,1 private bathroom
# 14227          4 guests,1 bedroom,4 beds,1 bathroom
# 14396   2 guests,1 bedroom,1 bed,1 private bathroom
# 14424  2 guests,1 bedroom,2 beds,1 private bathroom
#
#                                                amenities  \
# 26     Kitchen,Free residential garage on premises,Pr...
# 132                                                  NaN
# 136                                                  NaN
# 241                                                  NaN
# 261    Garden view,Mountain view,Kitchen,Wifi,Dedicat...
# ...                                                  ...
# 14119                                                NaN
# 14142                                                NaN
# 14227  Mountain view,Valley view,Kitchen,Wifi,Dedicat...
# 14396  Lake access,Wifi,Dedicated workspace,Free park...
# 14424                                                NaN
#
#                                             safety_rules  \
# 26                                                   NaN
# 132    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 136    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 241    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 261                                                  NaN
# ...                                                  ...
# 14119  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14142  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14227                                                NaN
# 14396                                                NaN
# 14424  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
#
#                                             hourse_rules  \
# 26                                                   NaN
# 132    Check-in: 4:00 pm - 8:00 pm,Check out: 10:00 a...
# 136    Check-in: 4:00 pm - 8:00 pm,Self check-in with...
# 241    Check-in: 2:00 pm - 6:00 pm,Check out: 10:00 a...
# 261                                                  NaN
# ...                                                  ...
# 14119  Check-in: 2:00 pm - 7:00 pm,Check out: 11:00 a...
# 14142  Check-in: 3:00 pm - 12:00 am,Check out: 12:00 ...
# 14227                                                NaN
# 14396                                                NaN
# 14424  Check-in: 2:00 pm - 11:00 pm,Check out: 9:00 a...
#
#                                                img_links              price
# 26     https://a0.muscache.com/im/pictures/944c4e82-c...  ₹15,052 per night
# 132    https://a0.muscache.com/im/pictures/miso/Hosti...   ₹6,669 per night
# 136    https://a0.muscache.com/im/pictures/miso/Hosti...   ₹8,336 per night
# 241    https://a0.muscache.com/im/pictures/50fc4b29-6...   ₹4,005 per night
# 261    https://a0.muscache.com/im/pictures/6770d413-d...   ₹7,191 per night
# ...                                                  ...                ...
# 14119  https://a0.muscache.com/im/pictures/210060b7-3...   ₹2,264 per night
# 14142  https://a0.muscache.com/im/pictures/75c685d6-0...   ₹3,302 per night
# 14227  https://a0.muscache.com/im/pictures/a250ff2d-a...   ₹6,790 per night
# 14396  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹2,759 per night
# 14424  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,168 per night
#
# [760 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id         169
# address           0
# features          0
# amenities       670
# safety_rules     92
# hourse_rules     92
# img_links         0
# price             0
# dtype: int64

# %%
df.dropna(subset=['host_id'],inplace= True)

# %%
df['amenities'].fillna('NO amnenities',inplace=True)
# Out:
# /tmp/ipython-input-482103728.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['amenities'].fillna('NO amnenities',inplace=True)

# %%
df.isnull().sum()
# Out:
# id               0
# name             0
# rating           0
# reviews          0
# host_name        0
# host_id          0
# address          0
# features         0
# amenities        0
# safety_rules    92
# hourse_rules    92
# img_links        0
# price            0
# dtype: int64

# %%
df['hourse_rules']
# Out:
# 0        Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2        Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3        Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9               Check-in: After 3:00 pm,No smoking,No pets
# 10       Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
#                                ...
# 14451    Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452    Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                              Check-in: After 3:00 pm
# 14454    Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455    Check-in: After 4:00 pm,Check out: 11:00 am,Se...
# Name: hourse_rules, Length: 10913, dtype: object

# %%
df['safety_rules'].fillna('No Safety Rules',inplace = True)
# Out:
# /tmp/ipython-input-3132175608.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['safety_rules'].fillna('No Safety Rules',inplace = True)

# %%
df['hourse_rules'].fillna('Check-in:Flexible,Check-out: 12:00 pm',inplace=True)

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# rating          0
# reviews         0
# host_name       0
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# dtype: int64

# %% [markdown]
# #2) Column wise cleaning

# %%
df.columns
# Out:
# Index(['id', 'name', 'rating', 'reviews', 'host_name', 'host_id', 'address',
#        'features', 'amenities', 'safety_rules', 'hourse_rules', 'img_links',
#        'price'],
#       dtype='object')

# %%
df['id']
# Out:
# 0        49849504
# 2        50699164
# 3        49871422
# 9        42075682
# 10       50425621
#            ...
# 14451    44697740
# 14452    29975283
# 14453    32977697
# 14454     8006146
# 14455    40547903
# Name: id, Length: 10913, dtype: int64

# %%
df['name']
# Out:
# 0                                           Perla bungalov
# 2                                        cottages sataplia
# 3                              Sapanca Breathable Bungalow
# 9                          The Cottage, Private Pool Villa
# 10       A private pension hut on the hillside of Sokli...
#                                ...
# 14451              Brown Dome House No. 3, full of healing
# 14452         Bubble Hotel Ubud with Bathtub under the Sky
# 14453                                     Paradise Eco Hub
# 14454       WisDOME - Mentigi Bay Village - Gilis - Lombok
# 14455     Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]
# Name: name, Length: 10913, dtype: object

# %%
df['rating'] = df['rating'].str.replace("New",'0.0')

# %%
df['rating']=df['rating'].astype(float)

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3627053830.py in <cell line: 0>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#              id                                               name  rating  \
# 0      49849504                                     Perla bungalov    4.71
# 2      50699164                                  cottages sataplia    4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.00
# 9      42075682                    The Cottage, Private Pool Villa    4.67
# 10     50425621  A private pension hut on the hillside of Sokli...    4.97
# ...         ...                                                ...     ...
# 14451  44697740            Brown Dome House No. 3, full of healing    4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky    4.67
# 14453  32977697                                   Paradise Eco Hub    4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85
#
#       reviews                             host_name      host_id  \
# 0          64   Entire bungalow hosted by Mehmetcan  357334205.0
# 2          68         Entire cabin hosted by Giorgi  409690853.0
# 3          13       Entire bungalow hosted by Melih  401873242.0
# 9           3         Entire home hosted by Sukanya  173126583.0
# 10         77                Farm stay hosted by 동현   81358542.0
# ...       ...                                   ...          ...
# 14451      16                  Dome hosted by Aidan  161552316.0
# 14452       6                 Tent hosted by Martha  118954227.0
# 14453       3  Private room in dome hosted by Silas  175214568.0
# 14454       7                Dome hosted by Cempaka     718423.0
# 14455      13                   Dome hosted by Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 9      Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# 10     Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 9           10 guests,4 bedrooms,6 beds,3 bathrooms
# 10              4 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 14451                          4 guests,8 bathrooms
# 14452     2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 beds,1 private bathroom
# 14454      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 9      Kitchen,Wifi,Free parking on premises,Private ...
# 10     Mountain view,Kitchen,Free on-street parking,C...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 10     󹀁,Airbnb's COVID-19 safety practices apply,Car...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9             Check-in: After 3:00 pm,No smoking,No pets
# 10     Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
# ...                                                  ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                            Check-in: After 3:00 pm
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...
#
#                                                img_links              price
# 0      https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 2      https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3      https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 9      https://a0.muscache.com/im/pictures/42d26843-4...  ₹30,486 per night
# 10     https://a0.muscache.com/im/pictures/miso/Hosti...   ₹9,052 per night
# ...                                                  ...                ...
# 14451  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,288 per night
# 14452  https://a0.muscache.com/im/pictures/5ba944b2-b...  ₹15,200 per night
# 14453  https://a0.muscache.com/im/pictures/1f442c84-4...   ₹9,103 per night
# 14454  https://a0.muscache.com/im/pictures/105116799/...  ₹42,262 per night
# 14455  https://a0.muscache.com/im/pictures/9b04ee4c-c...   ₹9,909 per night
#
# [10913 rows x 13 columns]

# %%
df['reviews'] = df['reviews'].str.replace(",", '')

# %%
df['reviews'] = df['reviews'].astype(int)

# %%
df['host_name'] = df['host_name'].str.split('by').str[1]

# %%
df['host_name'] = df['host_name'].str.strip()

# %%
df['host_id'] = df['host_id'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10913 entries, 0 to 14455
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10913 non-null  int64
#  1   name          10913 non-null  object
#  2   rating        10913 non-null  float64
#  3   reviews       10913 non-null  int64
#  4   host_name     10913 non-null  object
#  5   host_id       10913 non-null  object
#  6   address       10913 non-null  object
#  7   features      10913 non-null  object
#  8   amenities     10913 non-null  object
#  9   safety_rules  10913 non-null  object
#  10  hourse_rules  10913 non-null  object
#  11  img_links     10913 non-null  object
#  12  price         10913 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 1.2+ MB

# %%
df
# Out:
#              id                                               name  rating  \
# 0      49849504                                     Perla bungalov    4.71
# 2      50699164                                  cottages sataplia    4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.00
# 9      42075682                    The Cottage, Private Pool Villa    4.67
# 10     50425621  A private pension hut on the hillside of Sokli...    4.97
# ...         ...                                                ...     ...
# 14451  44697740            Brown Dome House No. 3, full of healing    4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky    4.67
# 14453  32977697                                   Paradise Eco Hub    4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85
#
#        reviews  host_name      host_id  \
# 0           64  Mehmetcan  357334205.0
# 2           68     Giorgi  409690853.0
# 3           13      Melih  401873242.0
# 9            3    Sukanya  173126583.0
# 10          77         동현   81358542.0
# ...        ...        ...          ...
# 14451       16      Aidan  161552316.0
# 14452        6     Martha  118954227.0
# 14453        3      Silas  175214568.0
# 14454        7    Cempaka     718423.0
# 14455       13       Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 9      Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# 10     Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 9           10 guests,4 bedrooms,6 beds,3 bathrooms
# 10              4 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 14451                          4 guests,8 bathrooms
# 14452     2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 beds,1 private bathroom
# 14454      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 9      Kitchen,Wifi,Free parking on premises,Private ...
# 10     Mountain view,Kitchen,Free on-street parking,C...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 10     󹀁,Airbnb's COVID-19 safety practices apply,Car...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9             Check-in: After 3:00 pm,No smoking,No pets
# 10     Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
# ...                                                  ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                            Check-in: After 3:00 pm
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...
#
#                                                img_links              price
# 0      https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 2      https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3      https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 9      https://a0.muscache.com/im/pictures/42d26843-4...  ₹30,486 per night
# 10     https://a0.muscache.com/im/pictures/miso/Hosti...   ₹9,052 per night
# ...                                                  ...                ...
# 14451  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,288 per night
# 14452  https://a0.muscache.com/im/pictures/5ba944b2-b...  ₹15,200 per night
# 14453  https://a0.muscache.com/im/pictures/1f442c84-4...   ₹9,103 per night
# 14454  https://a0.muscache.com/im/pictures/105116799/...  ₹42,262 per night
# 14455  https://a0.muscache.com/im/pictures/9b04ee4c-c...   ₹9,909 per night
#
# [10913 rows x 13 columns]

# %%
df.groupby('host_id')['host_name'].count().sort_values(ascending= False)
# Out:
# host_id
# 157378426.0    20
# 233211645.0    13
# 105199196.0    11
# 7455203.0      10
# 85667941.0      9
#                ..
# 59652772.0      1
# 59669198.0      1
# 59687931.0      1
# 59689593.0      1
# 59321932.0      1
# Name: host_name, Length: 9136, dtype: int64

# %%
df['country']=df['address'].str.split(',').str[-1].str.split()

# %%
df[['host_id','host_name']].value_counts()
# Out:
# host_id      host_name
# 157378426.0  Shanu              20
# 233211645.0  HotelSnow          13
# 105199196.0  Paolo              11
# 7455203.0    Alessandro&Anna    10
# 85667941.0   Temuri              9
#                                 ..
# 59652772.0   Katja               1
# 59669198.0   Bayu & Wayana       1
# 59687931.0   Evgeni              1
# 59689593.0   Kamolnate           1
# 59321932.0   Margarita           1
# Name: count, Length: 9136, dtype: int64

# %%
df['amenities'].str.split(',').str[0]
# Out:
# 0        Mountain view
# 2        Mountain view
# 3        Mountain view
# 9              Kitchen
# 10       Mountain view
#              ...
# 14451          Kitchen
# 14452             Wifi
# 14453             Wifi
# 14454          Kitchen
# 14455         Sea view
# Name: amenities, Length: 10913, dtype: object

# %%
df['hourse_rules']
# Out:
# 0        Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2        Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3        Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9               Check-in: After 3:00 pm,No smoking,No pets
# 10       Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
#                                ...
# 14451    Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452    Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                              Check-in: After 3:00 pm
# 14454    Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455    Check-in: After 4:00 pm,Check out: 11:00 am,Se...
# Name: hourse_rules, Length: 10913, dtype: object

# %%
df['Check-In'] = df['hourse_rules'].str.split(',').str[0].str.split('in:').str[1].str.strip()

# %%
df['Check-Out'] = df['hourse_rules'].str.split(',').str[1].str.split('out:').str[1].str.strip().fillna('12:00 pm')

# %%
df
# Out:
#              id                                               name  rating  \
# 0      49849504                                     Perla bungalov    4.71
# 2      50699164                                  cottages sataplia    4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.00
# 9      42075682                    The Cottage, Private Pool Villa    4.67
# 10     50425621  A private pension hut on the hillside of Sokli...    4.97
# ...         ...                                                ...     ...
# 14451  44697740            Brown Dome House No. 3, full of healing    4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky    4.67
# 14453  32977697                                   Paradise Eco Hub    4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85
#
#        reviews  host_name      host_id  \
# 0           64  Mehmetcan  357334205.0
# 2           68     Giorgi  409690853.0
# 3           13      Melih  401873242.0
# 9            3    Sukanya  173126583.0
# 10          77         동현   81358542.0
# ...        ...        ...          ...
# 14451       16      Aidan  161552316.0
# 14452        6     Martha  118954227.0
# 14453        3      Silas  175214568.0
# 14454        7    Cempaka     718423.0
# 14455       13       Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 9      Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# 10     Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 9           10 guests,4 bedrooms,6 beds,3 bathrooms
# 10              4 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 14451                          4 guests,8 bathrooms
# 14452     2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 beds,1 private bathroom
# 14454      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 9      Kitchen,Wifi,Free parking on premises,Private ...
# 10     Mountain view,Kitchen,Free on-street parking,C...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 10     󹀁,Airbnb's COVID-19 safety practices apply,Car...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9             Check-in: After 3:00 pm,No smoking,No pets
# 10     Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
# ...                                                  ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                            Check-in: After 3:00 pm
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...
#
#                                                img_links              price  \
# 0      https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 2      https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3      https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 9      https://a0.muscache.com/im/pictures/42d26843-4...  ₹30,486 per night
# 10     https://a0.muscache.com/im/pictures/miso/Hosti...   ₹9,052 per night
# ...                                                  ...                ...
# 14451  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,288 per night
# 14452  https://a0.muscache.com/im/pictures/5ba944b2-b...  ₹15,200 per night
# 14453  https://a0.muscache.com/im/pictures/1f442c84-4...   ₹9,103 per night
# 14454  https://a0.muscache.com/im/pictures/105116799/...  ₹42,262 per night
# 14455  https://a0.muscache.com/im/pictures/9b04ee4c-c...   ₹9,909 per night
#
#               country            Check-In Check-Out
# 0            [Turkey]            Flexible  12:00 pm
# 2           [Georgia]       After 1:00 pm  12:00 pm
# 3            [Turkey]       After 2:00 pm  12:00 pm
# 9          [Thailand]       After 3:00 pm  12:00 pm
# 10     [South, Korea]   3:00 pm - 9:00 pm  11:00 am
# ...               ...                 ...       ...
# 14451  [South, Korea]  3:00 pm - 11:00 pm  11:00 am
# 14452     [Indonesia]  3:00 pm - 10:00 pm  12:00 pm
# 14453        [Uganda]       After 3:00 pm  12:00 pm
# 14454     [Indonesia]            Flexible  12:00 pm
# 14455         [Japan]       After 4:00 pm  11:00 am
#
# [10913 rows x 16 columns]

# %%
del df['img_links']

# %%
df.head(5)
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#     reviews  host_name      host_id  \
# 0        64  Mehmetcan  357334205.0
# 2        68     Giorgi  409690853.0
# 3        13      Melih  401873242.0
# 9         3    Sukanya  173126583.0
# 10       77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# 10  Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
#
#                                    features  \
# 0      2 guests,2 bedrooms,1 bed,1 bathroom
# 2      4 guests,1 bedroom,3 beds,1 bathroom
# 3      4 guests,1 bedroom,2 beds,1 bathroom
# 9   10 guests,4 bedrooms,6 beds,3 bathrooms
# 10      4 guests,1 bedroom,1 bed,1 bathroom
#
#                                             amenities  \
# 0   Mountain view,Valley view,Lake access,Kitchen,...
# 2   Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3   Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 9   Kitchen,Wifi,Free parking on premises,Private ...
# 10  Mountain view,Kitchen,Free on-street parking,C...
#
#                                          safety_rules  \
# 0   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 10  󹀁,Airbnb's COVID-19 safety practices apply,Car...
#
#                                          hourse_rules              price  \
# 0   Check-in: Flexible,Check out: 12:00 pm,Pets ar...   ₹8,078 per night
# 2   Check-in: After 1:00 pm,Check out: 12:00 pm,Se...   ₹5,991 per night
# 3   Check-in: After 2:00 pm,Check out: 12:00 pm,No...  ₹11,339 per night
# 9          Check-in: After 3:00 pm,No smoking,No pets  ₹30,486 per night
# 10  Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...   ₹9,052 per night
#
#            country           Check-In Check-Out
# 0         [Turkey]           Flexible  12:00 pm
# 2        [Georgia]      After 1:00 pm  12:00 pm
# 3         [Turkey]      After 2:00 pm  12:00 pm
# 9       [Thailand]      After 3:00 pm  12:00 pm
# 10  [South, Korea]  3:00 pm - 9:00 pm  11:00 am

# %%
df['features'].str.split(',').str[0].value_counts()
# Out:
# features
# 2 guests     3213
# 4 guests     2298
# 6 guests     1270
# 3 guests     1109
# 5 guests      647
# 8 guests      618
# 16 guests     403
# 10 guests     356
# 12 guests     245
# 7 guests      234
# 9 guests      183
# 1 guest        94
# 14 guests      92
# 15 guests      81
# 11 guests      39
# 13 guests      31
# Name: count, dtype: int64

# %%
df['No_of_guest']=df['features'].str.split(',').str[0].str.split().str[0].astype(int)

# %%
df['price'] = df['price'].str.split().str[0].str.split('₹').str[1].str.replace(',','').str.strip().astype(int)

# %%
df['features']=df['features'].str.replace('bedroomss','bedroom').str.replace('bedrooms','bedroom').str.replace('beds','bed').str.replace('bathrooms','bathroom')

# %%
df['features']
# Out:
# 0                2 guests,2 bedroom,1 bed,1 bathroom
# 2                4 guests,1 bedroom,3 bed,1 bathroom
# 3                4 guests,1 bedroom,2 bed,1 bathroom
# 9               10 guests,4 bedroom,6 bed,3 bathroom
# 10               4 guests,1 bedroom,1 bed,1 bathroom
#                             ...
# 14451                            4 guests,8 bathroom
# 14452      2 guests,1 bedroom,1 bed,Toilet with sink
# 14453    2 guests,1 bedroom,2 bed,1 private bathroom
# 14454          8 guests,2 bedroom,4 bed,2.5 bathroom
# 14455            5 guests,1 bedroom,2 bed,1 bathroom
# Name: features, Length: 10913, dtype: object

# %%
df
# Out:
#              id                                               name  rating  \
# 0      49849504                                     Perla bungalov    4.71
# 2      50699164                                  cottages sataplia    4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.00
# 9      42075682                    The Cottage, Private Pool Villa    4.67
# 10     50425621  A private pension hut on the hillside of Sokli...    4.97
# ...         ...                                                ...     ...
# 14451  44697740            Brown Dome House No. 3, full of healing    4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky    4.67
# 14453  32977697                                   Paradise Eco Hub    4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85
#
#        reviews  host_name      host_id  \
# 0           64  Mehmetcan  357334205.0
# 2           68     Giorgi  409690853.0
# 3           13      Melih  401873242.0
# 9            3    Sukanya  173126583.0
# 10          77         동현   81358542.0
# ...        ...        ...          ...
# 14451       16      Aidan  161552316.0
# 14452        6     Martha  118954227.0
# 14453        3      Silas  175214568.0
# 14454        7    Cempaka     718423.0
# 14455       13       Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 9      Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# 10     Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                           features  \
# 0              2 guests,2 bedroom,1 bed,1 bathroom
# 2              4 guests,1 bedroom,3 bed,1 bathroom
# 3              4 guests,1 bedroom,2 bed,1 bathroom
# 9             10 guests,4 bedroom,6 bed,3 bathroom
# 10             4 guests,1 bedroom,1 bed,1 bathroom
# ...                                            ...
# 14451                          4 guests,8 bathroom
# 14452    2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 bed,1 private bathroom
# 14454        8 guests,2 bedroom,4 bed,2.5 bathroom
# 14455          5 guests,1 bedroom,2 bed,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 9      Kitchen,Wifi,Free parking on premises,Private ...
# 10     Mountain view,Kitchen,Free on-street parking,C...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 10     󹀁,Airbnb's COVID-19 safety practices apply,Car...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  price  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...   8078
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...   5991
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...  11339
# 9             Check-in: After 3:00 pm,No smoking,No pets  30486
# 10     Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...   9052
# ...                                                  ...    ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...   4288
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...  15200
# 14453                            Check-in: After 3:00 pm   9103
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...  42262
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...   9909
#
#               country            Check-In Check-Out  No_of_guest
# 0            [Turkey]            Flexible  12:00 pm            2
# 2           [Georgia]       After 1:00 pm  12:00 pm            4
# 3            [Turkey]       After 2:00 pm  12:00 pm            4
# 9          [Thailand]       After 3:00 pm  12:00 pm           10
# 10     [South, Korea]   3:00 pm - 9:00 pm  11:00 am            4
# ...               ...                 ...       ...          ...
# 14451  [South, Korea]  3:00 pm - 11:00 pm  11:00 am            4
# 14452     [Indonesia]  3:00 pm - 10:00 pm  12:00 pm            2
# 14453        [Uganda]       After 3:00 pm  12:00 pm            2
# 14454     [Indonesia]            Flexible  12:00 pm            8
# 14455         [Japan]       After 4:00 pm  11:00 am            5
#
# [10913 rows x 16 columns]

# %% [markdown]
# ## Questions for EDA:
# # 1)What are the most popular listing types based on ratings or number of reviews?
# # 2) Which countries have the most Airbnb listings?
# # 3)How does the number of reviews relate to the rating of a listing?
# #4) What are the most common amenities offered in the listings?
# #5) Is there a relationship between the price of a listing and the number of guests it can accommodate?
# #6) What are the typical check-in and check-out times?
# #7) Are there any patterns in safety rules or house rules across different locations or listing types?
# #8) How are the prices distributed across different countries or regions?
# #9)Can we identify any trends or patterns in the features offered (number of bedrooms, beds, bathrooms)?
# #10)What is the distribution of ratings? Are there many new listings with no ratings?

# %%
# Install ydata-profiling
# !pip install ydata-profiling -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 78.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.4 MB/s eta 0:00:00

# %%
# Generate the profiling report
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Titanic Dataset Profiling Report")
profile
# Display the report in the notebook
profile.to_notebook_iframe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
